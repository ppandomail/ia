# %%
nombre= 'pepe '
appellido= "osio"
'osio'*4
# Out:
# 'osioosioosioosio'

# %%
nombre==appellido
nombre<appellido
# Out:
# False

# %%
appellido="Osio"
nombre<appellido
# Out:
# False

# %%
"pepe"<"osio"
# Out:
# False

# %%
"pepe"<"Osio"
# Out:
# False

# %%
chr(0x41)
# Out:
# 'A'

# %%
chr(0x61)
# Out:
# 'a'

# %%
'N'<'a'
# Out:
# True

# %%
m="camioneta"
m.split()
# Out:
# ['camioneta']

# %%
m="camioneta auto moto"
m.split()
# Out:
# ['camioneta', 'auto', 'moto']

# %%
m.startswith('s')
# Out:
# False

# %%
m.startswith('c')
len(m)
print(nombre[-1:-2])

# %%
print(nombre[0:-1])
# Out:
# pepe

# %%
for k in range(2,16,2):
  print(m[k])
# Out:
# m
# o
# e
# a
# a
# t

# %%
while True:
  name=input('ingrese nombre')
  if name!= 'pepe':
    continue
  pwd=input('contraseña')
  if pwd=='papa':
    break
print('hola')
# Out:
# ingrese nombrepaco
# ingrese nombrearturo
# ingrese nombrepepe
# contraseñapepe
# ingrese nombrepepe
# contraseñapapa
# hola

# %%
import sys
res=input("salir")
if res=='exit':
  sys.exit
# Out:
# salirexit

# %%
lista4=[22,True, 'una lista', [1,7],True]
lista4[3][1]
lista4.count(True)
del lista4[2]
lista4.remove(True)
lista4
# Out:
# [22, [1, 7], True]
