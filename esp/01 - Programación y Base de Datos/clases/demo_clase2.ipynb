# %% [markdown]
# # Ejemplos Clase 2#

# %%
for i in range(5):
  print("hola que tal")
# Out:
# hola que tal
# hola que tal
# hola que tal
# hola que tal
# hola que tal

# %%
lista = [1,2,3,4,5]

for elemento in lista:
  print(elemento)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
nombres = ["pablo","carlos","maria"]

for nombre in nombres:
  print(nombre)

# %%
for k in range(2,16,2):
  print('k')

# %%
print('ingrese un nùmero')
num=int(input())
suma=0
while num!=0:
  suma=suma+num
  print('ingrese un nùmero')
  num=int(input())
print(suma)
# Out:
# ingrese un nùmero
# 3
# ingrese un nùmero
# 5
# ingrese un nùmero
# 7
# ingrese un nùmero
# 8
# ingrese un nùmero
# 6
# ingrese un nùmero
# 0
# 29

# %%
while True:
  name=input("ingrese nombre")
  if name == "pepe":
    break

print("Hola",name,"bienvenido al sistema")
# Out:
# ingrese nombrejorge
# ingrese nombrejuan
# ingrese nombrepedro
# ingrese nombrepepe
# Hola pepe bienvenido al sistema

# %%
while True:
  name=input('ingrese nombre')
  if name!= 'pepe':
    continue
  pwd=input('contraseña')
  if pwd=='papa':
    break
print('hola', name, 'ingreso valido')
# Out:
# ingrese nombrejorge
# ingrese nombrejuan
# ingrese nombrepepe
# contraseñacleopatra
# ingrese nombrepepe
# contraseñapapa
# hola pepe ingreso valido

# %% [markdown]
# **Listas:**

# %%
lista = [123,1234,"roman"]

print(len(lista))
# Out:
# 3

# %%
lista4=[22,True, 'una cadena', [1,7],True]
print(lista4[3][1])
print(lista4.count(True))
print(lista4[-3])
del lista4[2]
lista4.remove(True)
print(lista4)
# Out:
# 7
# 2
# una cadena
# [22, [1, 7], True]

# %% [markdown]
# ***Diccionarios***

# %%
dic1={21345:'perez',23456:'roni',32123:'ples'}
print(dic1)
# Out:
# {21345: 'perez', 23456: 'roni', 32123: 'ples'}

# %%
# cantidad de elementos del diccionario

print(len(dic1))
# Out:
# 3

# %%
dic1.values()
# Out:
# dict_values(['perez', 'roni', 'ples'])

# %%
dic1.get(23456)
# Out:
# 'roni'

# %%
dic1[23456]
# Out:
# 'roni'

# %%
tuplas=dic1.items()
for k,v in tuplas:
  print(k,'->',v)
# Out:
# 21345 -> perez
# 23456 -> roni
# 32123 -> ples

# %%
for k in dic1:
  print(k)
# Out:
# 21345
# 23456
# 32123

# %%
for k in dic1:
  print(dic1[k])
# Out:
# perez
# roni
# ples

# %%
dic1.pop(2346)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6411/666071130.py in <cell line: 0>()
# ----> 1 dic1.pop(2346)
#       2
#
# KeyError: 2346

# %%
print(dic1)
# Out:
# {21345: 'perez', 32123: 'ples'}

# %%
del dic1[213]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6411/20740137.py in <cell line: 0>()
# ----> 1 del dic1[213]
#
# KeyError: 213

# %%
print(dic1)
# Out:
# {32123: 'ples'}

# %% [markdown]
# **Conjuntos**

# %%
conjunto = set()
conjunto.add(3)
conjunto.add(4)
conjunto.add(1)
print(conjunto)
# Out:
# {1, 3, 4}

# %%
conjunto.remove(1)
conjunto.discard(4)
print(conjunto)
# Out:
# {3}

# %%
len(conjunto)
# Out:
# 1

# %%
1 in conjunto
# Out:
# False

# %%
conj={0,3,5,2,3,0,7}
print(conj)
# Out:
# {0, 2, 3, 5, 7}

# %%
print(list(conj))
# Out:
# [0, 2, 3, 5, 7]

# %%
list_numeros = []
suma = 0

print("ingrese 10 números:")
for i in range(10):
            num = float(input("Ingrese un número"))
            list_numeros.append(num)
            suma += num   #suma=suma+num
promedio = suma / len(list_numeros)
print("El promedio de los números ingresados es:",promedio)
print("Números mayores que el promedio:")
for num in list_numeros:
    if num > promedio:
            print(num)
# Out:
# ingrese 10 números:
# Ingrese un número3
# Ingrese un número5
# Ingrese un número8
# Ingrese un número7
# Ingrese un número34
# Ingrese un número21
# Ingrese un número65
# Ingrese un número33
# Ingrese un número9
# Ingrese un número15
# El promedio de los números ingresados es: 20.0
# Números mayores que el promedio:
# 34.0
# 21.0
# 65.0
# 33.0
