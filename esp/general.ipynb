# %% [markdown]
# # General
# ---

# %% [markdown]
# * Coord Esp. IA: Mg. Ing. Jorge Osio
# * josio@unaj.edu.ar

# %% [markdown]
# * Las clases quedan grabadas
# * Un curso por vez se dictan
# * Mismo usuario se accede al SIU y al campus
# * Asistente administrativa: Candela Oliva
# * 1ra cohorte
# * Matriculados: 52

# %% [markdown]
# ## Crono

# %% [markdown]
# |                |                      |
# | --             | --                   |
# | 24/08 al 28/09 | PROGRAMACIÓN         |
# | 05/10 al 16/11 | MÉTODOS ESTADÍSTICOS |
# | 23/11 al 21/12 | INTRO IA             |
